# %%
file = open("1000rnd.txt", "r")
print(file.read())
# Out:
# 28626
# 64486
# 83817
# 55054
# 88975
# 83558
# 49185
# 98923
# 76976
# 71305
# 22132
# 82046
# 21425
# 14052
# 60417
# 98330
# 15882
# 61001
# 20020
# 21458
# 3662
# 50654
# 25859
# 33926
# 52060
# 7229
# 66679
# 67212
# 59827
# 12300
# 43437
# 78596
# 41104
# 61476
# 70868
# 1061
# 21825
# 6195
# 91001
# 67076
# 97352
# 93194
# 49426
# 90086
# 7448
# 788
# 608
# 4935
# 23412
# 94922
# 25244
# 65148
# 90875
# 88778
# 70644
# 49096
# 65955
# 50322
# 7689
# 84981
# 47245
# 9197
# 18506
# 73154
# 40687
# 7768
# 51983
# 46268
# 98048
# 53255
# 55912
# 89574
# 6796
# 73136
# 25383
# 73588
# 77750
# 26820
# 48728
# 33296
# 16520
# 44018
# 60922
# 88157
# 95185
# 54722
# 87562
# 61750
# 78794
# 37527
# 75966
# 22934
# 69063
# 29952
# 408
# 7164
# 31265
# 34565
# 39015
# 45744
# 83596
# 6014
# 41913
# 38168
# 83649
# 59558
# 22332
# 69187
# 39064
# 83864
# 64143
# 44882
# 30918
# 55364
# 50831
# 24730
# 5685
# 36006
# 73887
# 91898
# 61096
# 16757
# 99360
# 86670
# 85035
# 2295
# 3018
# ...

# %%
file = "1000rnd.txt" 
fh = open(file, "r")
total = 0
with open("1000rnd.txt", 'r') as file:
            for line in file:
                # Convert each line to an integer and add it to the total
                total += int(line.strip())
print(total)
# Out:
# 49385029

# %%
file = "1000rnd.txt" 
fh = open(file, "r")

with open (file) in fh:
    for n in fh:
        n = n.strip()
        print(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 file = "1000rnd.txt"
#       2 fh = open(file, "r")
# ----> 4 with open (file) in fh:
#       5     for n in fh:
#       6         n = n.strip()
#
# TypeError: 'bool' object does not support the context manager protocol
